# %% [markdown]
# ### カリキュラム - 【AIコース】CNNによる画像分類 実装1

# %%
import keras
from keras.datasets import mnist
(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Using TensorFlow backend.
# /Users/yasu/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/importlib/_bootstrap.py:205: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
print(X_train.shape)
# Out:
# (60000, 28, 28)

# %%
print(y_train.shape)
# Out:
# (60000,)

# %%
print(X_test.shape)
# Out:
# (10000, 28, 28)

# %%
print(y_test.shape)
# Out:
# (10000,)

# %%
#画像サイズを取得しておく
img_rows = X_train[0].shape[1]
print(img_rows)
# Out:
# 28

# %%
img_cols = X_train[0].shape[0]
print(img_cols)
# Out:
# 28

# %%
# 正解ラベルをset型にすることで何種類に分類しているかを確認
num_classes = len(set(y_train))
print(num_classes)
# Out:
# 10

# %%
# チャネルを表す次元を用意
X_train = X_train.reshape(X_train.shape[0], img_rows, img_cols, 1)
print(X_train.shape)
# Out:
# (60000, 28, 28, 1)

# %%
X_test = X_test.reshape(X_test.shape[0], img_rows, img_cols, 1)
print(X_test.shape)
# Out:
# (10000, 28, 28, 1)

# %%
input_shape = X_train.shape[1:4]
print(input_shape)
# Out:
# (28, 28, 1)

# %%
X_train = X_train.astype("float32")
X_test = X_test.astype("float32")
X_train /= 255 # what is this???
X_test /= 255  # what is this???

# %%
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %% [markdown]
# ##### 小課題

# %%
from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.layers import Conv2D, MaxPooling2D

# %%
model = Sequential()

# %%
# 畳み込み層１ / ReLU
model.add(Conv2D(1, 
                 kernel_size = (3, 3),
                 strides = (1, 1),
                 padding = "same",
                 activation = "relu",
                 bias = True,
                 input_shape = input_shape))
# プーリング層１
model.add(MaxPooling2D(pool_size = (2, 2),
                       strides = None,
                       padding = "valid"))
# 畳み込み層２ / ReLU
model.add(Conv2D(1,
                 kernel_size = (3, 3),
                 strides = (1, 1),
                 padding = "same",
                 activation = "relu",))
# プーリング層２
model.add(MaxPooling2D(pool_size = (2, 2),
                      strides = None,
                      padding = "valid"))
# 全結合層
model.add(Flatten())
model.add(Dense(128, activation = "relu"))
model.add(Dense(num_classes, activation = "softmax"))

model.compile(loss = keras.losses.categorical_crossentropy,
              optimizer = keras.optimizers.Adadelta(),
              metrics = ["accuracy"])
# Out:
# /Users/yasu/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/ipykernel/__main__.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1, kernel_size=(3, 3), strides=(1, 1), padding="same", activation="relu", input_shape=(28, 28, 1..., use_bias=True)`

# %%
model.fit(X_train, y_train,
          batch_size = 128,
          epochs = 10,
          verbose = 1,
          validation_data = (X_test, y_test))
score = model.evaluate(X_test, y_test, verbose = 1)
print("Test loss: ", score[0])
print("Test accuracy: ", score[1])
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 9s 155us/step - loss: 0.7595 - acc: 0.7707 - val_loss: 0.3562 - val_acc: 0.8899
# Epoch 2/10
# 60000/60000 [==============================] - 9s 149us/step - loss: 0.3252 - acc: 0.9007 - val_loss: 0.2936 - val_acc: 0.9093
# Epoch 3/10
# 60000/60000 [==============================] - 9s 153us/step - loss: 0.2787 - acc: 0.9145 - val_loss: 0.2470 - val_acc: 0.9250
# Epoch 4/10
# 60000/60000 [==============================] - 10s 173us/step - loss: 0.2522 - acc: 0.9238 - val_loss: 0.2315 - val_acc: 0.9301
# Epoch 5/10
# 60000/60000 [==============================] - 10s 166us/step - loss: 0.2338 - acc: 0.9285 - val_loss: 0.2152 - val_acc: 0.9349
# Epoch 6/10
# 60000/60000 [==============================] - 11s 177us/step - loss: 0.2191 - acc: 0.9322 - val_loss: 0.2034 - val_acc: 0.9376
# Epoch 7/10
# 60000/60000 [==============================] - 10s 173us/step - loss: 0.2079 - acc: 0.9357 - val_loss: 0.1899 - val_acc: 0.9429
# Epoch 8/10
# 60000/60000 [==============================] - 11s 176us/step - loss: 0.1981 - acc: 0.9388 - val_loss: 0.1843 - val_acc: 0.9439
# Epoch 9/10
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.1889 - acc: 0.9410 - val_loss: 0.1798 - val_acc: 0.9465
# Epoch 10/10
# 60000/60000 [==============================] - 11s 192us/step - loss: 0.1819 - acc: 0.9446 - val_loss: 0.1675 - val_acc: 0.9501
# 10000/10000 [==============================] - 1s 124us/step
# Test loss:  0.167484045646
# Test accuracy:  0.9501
